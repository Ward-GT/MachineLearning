# %%
from BS_dataclass import SegmentationDataset
from config import *
from torch.utils.data import DataLoader
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset = SegmentationDataset(IMAGE_DATASET_PATH, MASK_DATASET_PATH, transform=None)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True, num_workers=0)
image, mask = next(iter(dataloader))
plt.imshow(transforms.ToPILImage()(image.squeeze()))

# %%
plt.imshow(transforms.ToPILImage()(mask.squeeze()))
